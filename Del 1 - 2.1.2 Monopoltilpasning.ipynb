# %% [markdown]
# # Sok-2030 Næringsøkonomi og konkuransestrategi
# ## Del 1 Grunleggende Mikroøkonomi
# ### Optimal tilpasning ved monopol
# Løsning av Pratice Problem 2.2
#
# Anta nå at det er monopol i markedet for produksjon av mobiltelefoner. Monopolisten har 50 like fabrikker, med samme kostnadsfunksjon per fabrikk som i 2.1: TC(q)= 100+𝑞2+10𝑞
# Markedsetterspørselen for mobiltelefoner er gitt ved en lineær etterspørsel lik:QD= (6000 −50𝑃)/.
# 9
# Marginale kostnader for monopolisten er lik: MC(q)=10+Q/2

# %% [markdown]
# b) Vis at monopolistens optimale produksjon er 𝑄_𝑀=275. Hva er den optimale prisen for monopolisten?

# %%
import sympy as sp
import numpy as np
from matplotlib import pyplot as plt

# %%
def marginalrevenue(Q):
    return (120-18*Q/50)

# %%
def marginalcost(Q):
    return (10+Q/25)

# %%
Q=sp.symbols('Q', real=True, positive=True)
equ=sp.Eq(marginalrevenue(Q),marginalcost(Q))
equ
# Out:
# Eq(120 - 9*Q/25, Q/25 + 10)

# %% [markdown]
# ### Optimal kvantum og pris for monopolbedriften er:

# %%
Q_equ=sp.solve(equ,Q)[0]
Q_equ
# Out:
# 275

# %%
def demand(Q):
    return (120-9*Q/50)

# %%
p_eq=demand(Q_equ)
p_eq
round(p_eq,2)
# Out:
# 70.50

# %%
#drawing 800 points in the interval 0.0 to 800
Q = np.linspace(1,800,800)

#drawing marginalrevenue
plt.plot(Q,marginalrevenue(Q),label='MR')

#drawing marginalcost
plt.plot(Q,marginalcost(Q),label='MC')
#drawing demand
plt.plot(Q,demand(Q),color='green',label='Etterspørsel')

#adding legend:
plt.legend(loc='lower right')

#setting the axis lables
plt.ylabel('Pris')
plt.xlabel('Enheter')

#setting the range of y values (the price) to be between 0 and 30, so that we can more
#easily see the equilibrium price
plt.ylim((-2,130))
# Out:
# (-2.0, 130.0)

# %% [markdown]
# c) Hva blir profitten for hver fabrikk?

# %%
q=sp.symbols('q', real=True, positive=True)
def Prod(q):
    return Q_equ/50

print (Prod(q))
# Out:
# 11/2

# %%
def Totalcost(q):
       return (100+10*(Q_equ/50)+(Q_equ/50)**2)

# %%
# profitt 
def profitt(Q):
    return (p_eq)*(Q_equ/50)-(Totalcost(q))
print (profitt(Q))
# Out:
# 405/2
